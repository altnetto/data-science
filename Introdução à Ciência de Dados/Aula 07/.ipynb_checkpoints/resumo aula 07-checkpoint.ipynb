# %% [markdown]
# <h3>Avaliação Semanal 07</h3>

# %% [markdown]
# Questão 1
#
# vertebralcolumn-2C
#
# árvore de decisão
# criterion = gini
# random state = 101
#
# Determinar:
# F1,
# precision
# - arredondar para 1 casa decimal

# %%
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

np.random.seed(42)

data = pd.read_csv('data/vertebralcolumn-2C.csv', header=(0))

data = data.to_numpy()
nrow,ncol = data.shape
y = data[:,-1]
X = data[:,0:ncol-1]

p = 0.2 # fracao de elementos no conjunto de teste
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = p, random_state = 2)

# %%
from sklearn import tree
# Cria o modelo usando o criterio Gini
model = tree.DecisionTreeClassifier(criterion = 'gini', random_state = 101)
# Ajusta o modelo usando os dados de treinamento
model.fit(x_train,y_train)
# realizar a predição
y_pred = model.predict(x_test)

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(model.fit(x_train,y_train),filled=True)
plt.show(True)

# %%
from sklearn.metrics import precision_score, f1_score

print('F1 score:', round(f1_score(y_test, y_pred, average="macro"),1))
print('\nPrecision:', round(precision_score(y_test, y_pred, average="macro"),1))
# Out:
# F1 score: 0.7
#
# Precision: 0.7

# %% [markdown]
# Questão 2 - Considere os dados do exercício anterior. Qual o valor das medidas F1 e Accuracy quando usamos o algoritmo random forest com 100 árvores? Arredonde para a primeira casa decimal.
#
# Use: model=RandomForestClassifier(n_estimators=100, random_state = 42)

# %%
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

np.random.seed(42)

data = pd.read_csv('data/vertebralcolumn-2C.csv', header=(0))

data = data.to_numpy()
nrow,ncol = data.shape
y = data[:,-1]
X = data[:,0:ncol-1]

p = 0.2 # fracao de elementos no conjunto de teste
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = p, random_state = 2)

# %%
from sklearn.ensemble import RandomForestClassifier
# Cria o modelo usando o criterio Gini
model = RandomForestClassifier(n_estimators=100, random_state = 42)
# Ajusta o modelo usando os dados de treinamento
model.fit(x_train,y_train)
# realizar a predição
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import precision_score, recall_score, classification_report, accuracy_score, f1_score

print('Accuracy:', round(accuracy_score(y_pred, y_test),1))
print('F1 score:', round(f1_score(y_test, y_pred, average="macro"),1))
# Out:
# Accuracy: 0.9
# F1 score: 0.9
